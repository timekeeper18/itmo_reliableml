# %%
import os
import numpy as np
import wandb

# %%
wandb.login()
# Out:
# wandb: Currently logged in as: parshin_d (dentist_ai). Use `wandb login --relogin` to force relogin
# True

# %%
wandb.init(entity="dentist_ai", project="Dentist_AI")
# Out:
# wandb version 0.16.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.11
# Run data is saved locally in <code>E:\NEW_MACHINE\Jupyter\ML_System_Design\wandb\run-20231111_213646-s34el313</code>
# Syncing run <strong><a href='https://wandb.ai/dentist_ai/Dentist_AI/runs/s34el313' target="_blank">northern-sunset-71</a></strong> to <a href='https://wandb.ai/dentist_ai/Dentist_AI' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/dentist_ai/Dentist_AI' target="_blank">https://wandb.ai/dentist_ai/Dentist_AI</a>
#  View run at <a href='https://wandb.ai/dentist_ai/Dentist_AI/runs/s34el313' target="_blank">https://wandb.ai/dentist_ai/Dentist_AI/runs/s34el313</a>
# ...

# %%
artifact = wandb.Artifact('dentasis_v30_4_Dental_disease_detection_Occlus', type='dataset')

# %%
path_to_data_dir = "E:/NEW_MACHINE/Jupyter/ML_System_Design/Clear_Datasets/dentasis_v30_4_Dental_disease_detection_Occlus_v0-v0/"


artifact.add_dir(path_to_data_dir)
wandb.log_artifact(artifact)
# Out:
# wandb: Adding directory to artifact (E:\NEW_MACHINE\Jupyter\ML_System_Design\Clear_Datasets\dentasis_v30_4_Dental_disease_detection_Occlus_v0-v0)... Done. 0.4s
# <Artifact dentasis_v30_4_Dental_disease_detection_Occlus>

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">northern-sunset-71</strong> at: <a href='https://wandb.ai/dentist_ai/Dentist_AI/runs/s34el313' target="_blank">https://wandb.ai/dentist_ai/Dentist_AI/runs/s34el313</a><br/>Synced 6 W&B file(s), 0 media file(s), 1151 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20231111_213646-s34el313\logs</code>
